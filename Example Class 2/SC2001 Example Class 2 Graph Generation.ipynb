# %% [markdown]
# <h3>Import libraries</h3>

# %%
import random
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <h3>Function to generate Adjacency Matrix</h3>

# %%
def generateAdjMatrix(num_of_vertices):
    adj_matrix = []
    for i in range(num_of_vertices):
        adj_lst = []
        if i == 0:
            adj_lst = [0] + [random.randint(1,10) for x in range(num_of_vertices-1)]
            adj_matrix.append(adj_lst)
        else:
            j = 0
            while j < i:
                adj_lst.append(adj_matrix[j][i])
                j += 1
            adj_lst.append(0)
            adj_lst += [random.randint(2,10) for x in range(num_of_vertices-1 - i)]
            adj_matrix.append(adj_lst)
    return adj_matrix

# %% [markdown]
# <h3>Graph with 3 vertices</h3>

# %%
num_of_vertices = 3

adj_matrix = generateAdjMatrix(num_of_vertices)
G = nx.Graph()
for i in range(len(adj_matrix)):
    for j in range(i, len(adj_matrix[i])):
        if adj_matrix[i][j] != 0:
            G.add_edge(i, j, weight=adj_matrix[i][j])
            
plt.figure(figsize=(10,10))
pos = nx.spring_layout(G, seed=num_of_vertices)
nx.draw(G, pos, with_labels = True)
nx.draw_networkx_edge_labels(G, pos, edge_labels=nx.get_edge_attributes(G, "weight"))
# Out:
# {(0, 1): Text(-0.20546250269059246, -0.025356709118924403, '1'),
#  (0, 2): Text(0.11501832800314382, 0.4999999999999995, '6'),
#  (1, 2): Text(0.09044417468744868, -0.4746432908810761, '4')}

# %%
print("The Adjacency Matrix for Graph 1 is:")
for lst in adj_matrix:
    print(lst)
# Out:
# The Adjacency Matrix for Graph 1 is:
# [0, 1, 6]
# [1, 0, 4]
# [6, 4, 0]

# %% [markdown]
# <h3>Graph with 5 vertices</h3>

# %%
num_of_vertices = 5

adj_matrix = generateAdjMatrix(num_of_vertices)
G = nx.Graph()
for i in range(len(adj_matrix)):
    for j in range(i, len(adj_matrix[i])):
        if adj_matrix[i][j] != 0:
            G.add_edge(i, j, weight=adj_matrix[i][j])
            
plt.figure(figsize=(10,10))
pos = nx.spring_layout(G, seed=num_of_vertices)
nx.draw(G, pos, with_labels = True)
nx.draw_networkx_edge_labels(G, pos, edge_labels=nx.get_edge_attributes(G, "weight"))
# Out:
# {(0, 1): Text(-0.3766345697819017, 0.5569714072256031, '2'),
#  (0, 2): Text(-0.017867225549259402, 0.20231313751216548, '8'),
#  (0, 3): Text(-0.07589383699414004, -0.27758783647433194, '3'),
#  (0, 4): Text(-0.5841535716969724, -0.3107824865866273, '10'),
#  (1, 2): Text(0.3085310073503545, 0.6453417302865623, '4'),
#  (1, 3): Text(0.25050439590547385, 0.16544075630006488, '4'),
#  (1, 4): Text(-0.25775533879735846, 0.1322461061877695, '4'),
#  (2, 3): Text(0.6092717401381161, -0.1892175134133728, '7'),
#  (2, 4): Text(0.10101200543528382, -0.2224121635256682, '3'),
#  (3, 4): Text(0.04298539399040319, -0.7023131375121656, '9')}

# %%
print("The Adjacency Matrix for Graph 2 is:")
for lst in adj_matrix:
    print(lst)
# Out:
# The Adjacency Matrix for Graph 2 is:
# [0, 2, 8, 3, 10]
# [2, 0, 4, 4, 4]
# [8, 4, 0, 7, 3]
# [3, 4, 7, 0, 9]
# [10, 4, 3, 9, 0]

# %% [markdown]
# <h3>Graph with 7 vertices</h3>

# %%
num_of_vertices = 7

adj_matrix = generateAdjMatrix(num_of_vertices)
G = nx.Graph()
for i in range(len(adj_matrix)):
    for j in range(i, len(adj_matrix[i])):
        if adj_matrix[i][j] != 0:
            G.add_edge(i, j, weight=adj_matrix[i][j])
            
plt.figure(figsize=(15,15))
pos = nx.spring_layout(G, seed=num_of_vertices)
nx.draw(G, pos, with_labels = True)
nx.draw_networkx_edge_labels(G, pos, edge_labels=nx.get_edge_attributes(G, "weight"))
# Out:
# {(0, 1): Text(-0.3422802089545014, 0.27514310496384065, '2'),
#  (0, 2): Text(0.13254957196700856, 0.30954279872983914, '2'),
#  (0, 3): Text(-0.15216908220699363, 0.674752216801016, '8'),
#  (0, 4): Text(-0.4866148899964015, 0.573457475638449, '6'),
#  (0, 5): Text(0.1950913559038333, 0.624584313590162, '3'),
#  (0, 6): Text(-0.05106999518786201, 0.042520090276693234, '1'),
#  (1, 2): Text(0.07206666240247403, -0.41531409630632027, '6'),
#  (1, 3): Text(-0.21265199177152816, -0.050104678235143335, '8'),
#  (1, 4): Text(-0.5470977995609361, -0.1513994193977104, '8'),
#  (1, 5): Text(0.13460844633929878, -0.10027258144599738, '4'),
#  (1, 6): Text(-0.11155290475239654, -0.6823368047594661, '5'),
#  (2, 3): Text(0.2621777891499818, -0.01570498446914484, '6'),
#  (2, 4): Text(-0.07226801863942606, -0.11699972563171192, '3'),
#  (2, 5): Text(0.6094382272608088, -0.06587288767999888, '8'),
#  (2, 6): Text(0.3632768761691134, -0.6479371109934676, '10'),
#  (3, 4): Text(-0.3569866728134283, 0.248209692439465, '9'),
#  (3, 5): Text(0.32471957308680655, 0.299336530391178, '8'),
#  (3, 6): Text(0.07855822199511124, -0.2827276929222907, '2'),
#  (4, 5): Text(-0.00972623470260131, 0.198041789228611, '3'),
#  (4, 6): Text(-0.2558875857942966, -0.3840224340848578, '4'),
#  (5, 6): Text(0.42581866010593816, -0.3328955961331448, '5')}

# %%
print("The Adjacency Matrix for Graph 3 is:")
for lst in adj_matrix:
    print(lst)
# Out:
# The Adjacency Matrix for Graph 3 is:
# [0, 2, 2, 8, 6, 3, 1]
# [2, 0, 6, 8, 8, 4, 5]
# [2, 6, 0, 6, 3, 8, 10]
# [8, 8, 6, 0, 9, 8, 2]
# [6, 8, 3, 9, 0, 3, 4]
# [3, 4, 8, 8, 3, 0, 5]
# [1, 5, 10, 2, 4, 5, 0]
